# %% [markdown]
# This source code created by IndianAIProduction.com team https://indianaiproduction.com/k-nearest-neighbor-regression/
#
# Video on
#
# K Nearest Neighbor Regression Algorithm Explain with Project in Hindi |Machine Learning Tutorial: https://youtu.be/2M08i_drnkI
#
# K Nearest Neighbor Classification Algorithm Explain with Project in Hindi |Machine Learning Tutorial: https://youtu.be/MqHUClKfQy8
#
# for video tutorial visit our youtube channel www.youtube.com\IndianAIProduction

# %% [markdown]
# ## Business Problem - Predict the Price of Bangalore House

# %% [markdown]
# **Using** K Nearest Neighbor Regression - Supervised Machine Learning Algorithm

# %% [markdown]
# ### Load Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Load Data

# %%
path = r"https://drive.google.com/uc?export=download&id=1xxDtrZKfuWQfl-6KA9XEd_eatitNPnkB" 
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    bath  balcony  ...  location_Mahadevpura  location_Tumkur Road
# 0   3.0      2.0  ...                     0                     0
# 1   3.0      3.0  ...                     0                     0
# 2   3.0      2.0  ...                     0                     0
# 3   2.0      2.0  ...                     0                     0
# 4   2.0      2.0  ...                     0                     0
#
# [5 rows x 108 columns]

# %% [markdown]
# ## Split Data

# %%
X = df.drop('price', axis=1)
y = df['price']

print('Shape of X = ', X.shape)
print('Shape of y = ', y.shape)
# Out:
# Shape of X =  (7120, 107)
# Shape of y =  (7120,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=51)

print('Shape of X_train = ', X_train.shape)
print('Shape of y_train = ', y_train.shape)
print('Shape of X_test = ', X_test.shape)
print('Shape of y_test = ', y_test.shape)
# Out:
# Shape of X_train =  (5696, 107)
# Shape of y_train =  (5696,)
# Shape of X_test =  (1424, 107)
# Shape of y_test =  (1424,)

# %% [markdown]
# ##K Nearest Neighbor Regression - ML Model Training

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
regressor = KNeighborsRegressor(n_neighbors=5)
regressor.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
regressor.score(X_test, y_test)
# Out:
# 0.8858213777326956

# %% [markdown]
# ## Predict the value of Home

# %%
  X_test.iloc[-1, :]
# Out:
# bath                               2.000000
# balcony                            0.000000
# total_sqft_int                  1566.000000
# bhk                                2.000000
# price_per_sqft                 11494.252874
#                                    ...
# location_Hosur Road                0.000000
# location_Horamavu Banaswadi        0.000000
# location_Domlur                    0.000000
# location_Mahadevpura               0.000000
# location_Tumkur Road               0.000000
# Name: 43, Length: 107, dtype: float64

# %%
regressor.predict([X_test.iloc[-1, :]])
# Out:
# array([184.4])

# %%
y_test.iloc[-1]
# Out:
# 180.0

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 77.378,  39.808, 120.2  , ...,  33.405,  63.   , 184.4  ])

# %%
y_test
# Out:
# 2435     80.00
# 3113     40.00
# 426     120.00
# 1124     79.00
# 1161     45.00
#          ...
# 2078     28.34
# 6855     84.00
# 4381     32.00
# 3862     63.00
# 43      180.00
# Name: price, Length: 1424, dtype: float64

# %% [markdown]
# Ab milenge next tutorial me,Tab tak ke liye SIKHATE SIKHATE kuch IMPLEMENT karte raho, Thank You.....-:)
